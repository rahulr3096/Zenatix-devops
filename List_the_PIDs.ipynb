# %%
import psutil
def getListOfProcessSortedByMemory():
    '''
    Get list of running process sorted by Memory Usage
    '''
    listOfProcObjects = []
    # Iterate over the list
    for proc in psutil.process_iter():
       try:
           # Fetch process details as dict
           pinfo = proc.as_dict(attrs=['pid', 'name', 'username'])
           pinfo['vms'] = proc.memory_info().vms / (1024 * 1024)
           # Append dict to list
           listOfProcObjects.append(pinfo);
       except (psutil.NoSuchProcess, psutil.AccessDenied, psutil.ZombieProcess):
           pass
    # Sort list of dict by key vms i.e. memory usage
    listOfProcObjects = sorted(listOfProcObjects, key=lambda procObj: procObj['vms'], reverse=True)
    return listOfProcObjects
def main():
    print("*** Iterate over all running process and print process ID & Name ***")
    # Iterate over all running process
    for proc in psutil.process_iter():
        try:
            # Get process name & pid from process object.
            processName = proc.name()
            processID = proc.pid
            print(processName , ' ::: ', processID)
        except (psutil.NoSuchProcess, psutil.AccessDenied, psutil.ZombieProcess):
            pass
    print('*** list of top 40 running processes ***')
    listOfProcessNames = list()
    # Iterate over all running processes
    for proc in psutil.process_iter():
       # Get process detail as dictionary
       
       pInfoDict = proc.as_dict(attrs=['pid', 'name', 'cpu_percent'])
       # Append dict of process detail in list
       listOfProcessNames.append(pInfoDict)
    # Iterate over the list of dictionary and print each elem
    for elem in listOfProcessNames[:40]:
        print(elem)
    print('*** Top 5 process with highest memory usage ***')
    listOfRunningProcess = getListOfProcessSortedByMemory()
    for elem in listOfRunningProcess[:5] :
        print(elem)
if __name__ == '__main__':
   main()
# Out:
# *** Iterate over all running process and print process ID & Name ***
# System Idle Process  :::  0
# System  :::  4
# Registry  :::  100
# smss.exe  :::  392
# csrss.exe  :::  544
# wininit.exe  :::  636
# svchost.exe  :::  648
# services.exe  :::  708
# lsass.exe  :::  716
# python.exe  :::  728
# svchost.exe  :::  840
# svchost.exe  :::  860
# fontdrvhost.exe  :::  868
# WUDFHost.exe  :::  928
# svchost.exe  :::  976
# svchost.exe  :::  1192
# svchost.exe  :::  1224
# svchost.exe  :::  1276
# svchost.exe  :::  1296
# svchost.exe  :::  1356
# svchost.exe  :::  1376
# svchost.exe  :::  1420
# svchost.exe  :::  1548
# svchost.exe  :::  1584
# ctfmon.exe  :::  1592
# svchost.exe  :::  1612
# csrss.exe  :::  1636
# svchost.exe  :::  1700
# svchost.exe  :::  1728
# svchost.exe  :::  1760
# svchost.exe  :::  1788
# svchost.exe  :::  1808
# svchost.exe  :::  1844
# svchost.exe  :::  1896
# svchost.exe  :::  2040
# svchost.exe  :::  2120
# svchost.exe  :::  2144
# svchost.exe  :::  2204
# svchost.exe  :::  2220
# svchost.exe  :::  2240
# svchost.exe  :::  2288
# elasticsearch.exe  :::  2332
# svchost.exe  :::  2356
# svchost.exe  :::  2364
# svchost.exe  :::  7416
# chrome.exe  :::  7440
# chrome.exe  :::  7468
# svchost.exe  :::  7508
# svchost.exe  :::  7644
# LockApp.exe  :::  7656
# RuntimeBroker.exe  :::  7676
# chrome.exe  :::  7700
# python.exe  :::  7712
# python.exe  :::  7772
# svchost.exe  :::  7800
# chrome.exe  :::  7892
# dllhost.exe  :::  8104
# chrome.exe  :::  8284
# SecurityHealthService.exe  :::  8400
# SecurityHealthSystray.exe  :::  8516
# svchost.exe  :::  8548
# winlogon.exe  :::  8584
# CONTRO~1.EXE  :::  8608
# dwm.exe  :::  8616
# conhost.exe  :::  8620
# chrome.exe  :::  8704
# RuntimeBroker.exe  :::  8796
# SynTPEnh.exe  :::  8824
# svchost.exe  :::  8996
# svchost.exe  :::  9136
# chrome.exe  :::  9192
# chrome.exe  :::  9268
# chrome.exe  :::  9340
# svchost.exe  :::  9460
# SearchFilterHost.exe  :::  9548
# GoogleCrashHandler.exe  :::  9884
# chrome.exe  :::  9920
# GoogleCrashHandler64.exe  :::  9968
# svchost.exe  :::  10000
# chrome.exe  :::  10156
# SgrmBroker.exe  :::  10220
# chrome.exe  :::  10228
# sihost.exe  :::  10296
# chrome.exe  :::  10440
# python.exe  :::  10444
# python.exe  :::  11044
# RuntimeBroker.exe  :::  11124
# chrome.exe  :::  11180
# chrome.exe  :::  11244
# conhost.exe  :::  11248
# SearchApp.exe  :::  11252
# chrome.exe  :::  11336
# svchost.exe  :::  11376
# svchost.exe  :::  11452
# SystemSettings.exe  :::  11560
# svchost.exe  :::  11888
# RuntimeBroker.exe  :::  12024
# ApplicationFrameHost.exe  :::  12336
# svchost.exe  :::  12708
# python.exe  :::  12808
# SettingSyncHost.exe  :::  13096
# YourPhone.exe  :::  13156
# chrome.exe  :::  13204
# SearchProtocolHost.exe  :::  13684
# chrome.exe  :::  13764
# chrome.exe  :::  13872
# explorer.exe  :::  13948
# *** list of top 40 running processes ***
# {'pid': 0, 'cpu_percent': 373.0, 'name': 'System Idle Process'}
# {'pid': 4, 'cpu_percent': 1.9, 'name': 'System'}
# {'pid': 100, 'cpu_percent': 0.0, 'name': 'Registry'}
# {'pid': 392, 'cpu_percent': 0.0, 'name': 'smss.exe'}
# {'pid': 544, 'cpu_percent': 0.0, 'name': 'csrss.exe'}
# {'pid': 636, 'cpu_percent': 0.0, 'name': 'wininit.exe'}
# {'pid': 648, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 708, 'cpu_percent': 0.0, 'name': 'services.exe'}
# {'pid': 716, 'cpu_percent': 0.0, 'name': 'lsass.exe'}
# {'pid': 728, 'cpu_percent': 0.0, 'name': 'python.exe'}
# {'pid': 840, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 860, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 868, 'cpu_percent': 0.0, 'name': 'fontdrvhost.exe'}
# {'pid': 928, 'cpu_percent': 0.0, 'name': 'WUDFHost.exe'}
# {'pid': 976, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 1192, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 1224, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 1276, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 1296, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 1356, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 1376, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 1420, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 1548, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 1584, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 1592, 'cpu_percent': 0.3, 'name': 'ctfmon.exe'}
# {'pid': 1612, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 1636, 'cpu_percent': 0.1, 'name': 'csrss.exe'}
# {'pid': 1700, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 1728, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 1760, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 1788, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 1808, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 1844, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 1896, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 2040, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 2120, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 2144, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 2204, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 2220, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# {'pid': 2240, 'cpu_percent': 0.0, 'name': 'svchost.exe'}
# *** Top 5 process with highest memory usage ***
# {'pid': 7028, 'username': None, 'name': 'java.exe', 'vms': 2350.04296875}
# {'pid': 2784, 'username': None, 'name': 'MsMpEng.exe', 'vms': 668.0859375}
# {'pid': 4392, 'username': None, 'name': 'mysqld.exe', 'vms': 338.2734375}
# {'pid': 4792, 'username': None, 'name': 'MoUsoCoreWorker.exe', 'vms': 330.13671875}
# {'pid': 8284, 'username': 'DESKTOP-N1JV4AG\\HP', 'name': 'chrome.exe', 'vms': 175.234375}
